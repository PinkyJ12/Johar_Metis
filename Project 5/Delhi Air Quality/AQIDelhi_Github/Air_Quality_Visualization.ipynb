# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_BeyondIndex=pd.read_csv('NEWData/Combined.csv',parse_dates=['Date'])

# %%
df_BeyondIndex.head()
# Out:
#                      PM2.5
# Date
# 2015-02-24 04:00:00    186
# 2015-02-24 05:00:00    179
# 2015-02-24 06:00:00    195
# 2015-02-24 07:00:00    207
# 2015-02-24 08:00:00    275

# %%
df_BeyondIndex=df_BeyondIndex[['Date','PM2.5']]

# %%
df_BeyondIndex.set_index('Date',inplace=True)

# %%
ts=df_BeyondIndex['PM2.5']

# %%
ts[ts==-999]=np.nan

# %%
ts.isnull().sum()
# Out:
# 0

# %%
ts = ts.fillna(ts.ffill())

# %%
ts.to_csv("DelhiAQIBeyondIndex.csv")

# %%
ts[ts>900]
# Out:
# Date
# 2015-11-12 00:00:00     976
# 2016-10-31 01:00:00     975
# 2016-10-31 02:00:00    1126
# 2016-10-31 03:00:00    1126
# 2017-10-20 08:00:00    1022
# 2017-10-20 09:00:00    1031
# 2017-10-20 10:00:00     983
# 2017-11-08 16:00:00    1010
# 2017-11-08 17:00:00     987
# 2017-11-08 18:00:00     938
# 2017-11-08 19:00:00     913
# Name: PM2.5, dtype: int64

# %%
df=pd.read_csv("DelhiAQIBeyondIndex.csv",names=["Date","Delhi_AQI"],parse_dates=['Date'])
df_LA=pd.read_csv("USA_Combined_DataFrame.csv",parse_dates=['Date'])

# %%
#df_LA.columns
df.columns
# Out:
# Index(['Date', 'Delhi_AQI'], dtype='object')

# %%
df_LA=df_LA[['Date','DAILY_AQI_VALUE']]

# %%
df.head()
#df_LA.head()
# Out:
#                  Date  Delhi_AQI
# 0 2015-02-24 04:00:00      186.0
# 1 2015-02-24 05:00:00      179.0
# 2 2015-02-24 06:00:00      195.0
# 3 2015-02-24 07:00:00      207.0
# 4 2015-02-24 08:00:00      275.0

# %%
df.set_index('Date', inplace=True)
df_LA.set_index('Date', inplace=True)

# %%
ts1=df.resample('D').mean()
ts=df_LA.resample('D').mean()

# %%
# ts1_Good=ts1[ts1.Delhi_AQI.between(0,50, inclusive=True)]
# ts1_Moderate=ts1[ts1.Delhi_AQI.between(51,100, inclusive=True) ]
# ts1_UnhealthySGroup = ts1[ts1.Delhi_AQI.between(101,150, inclusive=True) ]
# ts1_Unhealthy=ts1[ts1.Delhi_AQI.between(151,200, inclusive=True) ]
# ts1_VUnhealthy=ts1[ts1.Delhi_AQI.between(201,300, inclusive=True) ]
# ts1_Hazardous=ts1[ts1.Delhi_AQI.between(301,500, inclusive=True) ]

# %%
# ts_Good=ts[ts.DAILY_AQI_VALUE.between(0,50, inclusive=True)]
# ts_Moderate=ts[ts.DAILY_AQI_VALUE.between(51,100, inclusive=True) ]
# ts_UnhealthySGroup = ts[ts.DAILY_AQI_VALUE.between(101,150, inclusive=True) ]
# ts_Unhealthy=ts[ts.DAILY_AQI_VALUE.between(151,200, inclusive=True) ]
#ts_VUnhealthy=ts[ts.DAILY_AQI_VALUE.between(201,300, inclusive=True) ]
#ts_Hazardous=ts[ts.DAILY_AQI_VALUE.between(301,500, inclusive=True) ]

# %%
ts1_Good.rename(columns={"Delhi_AQI": "Good"},inplace=True)
ts1_Moderate.rename(columns={"Delhi_AQI": "Moderate"},inplace=True)
ts1_UnhealthySGroup.rename(columns={"Delhi_AQI": "UnhealthySensitiveGroup"},inplace=True)
ts1_Unhealthy.rename(columns={"Delhi_AQI": "Unhealthy"},inplace=True)
ts1_VUnhealthy.rename(columns={"Delhi_AQI": "VeryUnhealthy"},inplace=True)
ts1_Hazardous.rename(columns={"Delhi_AQI": "Hazardous"},inplace=True)
# Out:
# /Users/pinkyjohar/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
ts_Good.rename(columns={"DAILY_AQI_VALUE": "Good"},inplace=True)
ts_Moderate.rename(columns={"DAILY_AQI_VALUE": "Moderate"},inplace=True)
ts_UnhealthySGroup.rename(columns={"DAILY_AQI_VALUE": "UnhealthySensitiveGroup"},inplace=True)
ts_Unhealthy.rename(columns={"DAILY_AQI_VALUE": "Unhealthy"},inplace=True)
#ts_VUnhealthy.rename(columns={"DAILY_AQI_VALUE": "VeryUnhealthy"},inplace=True)
#ts_Hazardous.rename(columns={"DAILY_AQI_VALUE": "Hazardous"},inplace=True)

# df_Good.rename(columns='Date',inplace=True)
# df_Moderate.set_index('Date',inplace=True)
# df_UnhealthySGroup.set_index('Date',inplace=True)
# df_Unhealthy.set_index('Date',inplace=True)
# df_VUnhealthy.set_index('Date',inplace=True)
# df_Hazardous.set_index('Date',inplace=True)
# Out:
# /Users/pinkyjohar/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
# df_Good.set_index('Date',inplace=True)
# df_Moderate.set_index('Date',inplace=True)
# df_UnhealthySGroup.set_index('Date',inplace=True)
# df_Unhealthy.set_index('Date',inplace=True)
# df_VUnhealthy.set_index('Date',inplace=True)
# df_Hazardous.set_index('Date',inplace=True)

# %%
ts_Unhealthy.head()
# Out:
# Empty DataFrame
# Columns: [Unhealthy]
# Index: []

# %%
data=pd.DataFrame()

# %%
data1=pd.DataFrame()

# %%
data.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data1=data1.append(ts1_Good)
data1=data1.append(ts1_Moderate)
data1=data1.append(ts1_UnhealthySGroup)
data1=data1.append(ts1_Unhealthy)
data1=data1.append(ts1_VUnhealthy)
data1=data1.append(ts1_Hazardous)

# %%
data=data.append(ts_Good)
data=data.append(ts_Moderate)
data=data.append(ts_UnhealthySGroup)
data=data.append(ts_Unhealthy)
#data=data.append(ts_VUnhealthy)
#data=data.append(ts_Hazardous)

# %%
# Make data
#data = pd.DataFrame(df_Good,df_Moderate,df_UnhealthySGroup,df_VUnhealthy,df_Hazardous)
data1.head(5)
# Out:
#                  Good  Hazardous  Moderate  Unhealthy  \
# Date
# 2015-03-02  37.458333        NaN       NaN        NaN
# 2015-03-07  49.583333        NaN       NaN        NaN
# 2015-03-08  35.041667        NaN       NaN        NaN
# 2015-03-09  47.500000        NaN       NaN        NaN
# 2015-03-15  21.125000        NaN       NaN        NaN
#
#             UnhealthySensitiveGroup  VeryUnhealthy
# Date
# 2015-03-02                      NaN            NaN
# 2015-03-07                      NaN            NaN
# 2015-03-08                      NaN            NaN
# 2015-03-09                      NaN            NaN
# 2015-03-15                      NaN            NaN

# %%
data2=data.copy()

# %%
data2.fillna(0)
# Out:
#                  Good  Hazardous   Moderate  Unhealthy  \
# Date
# 2015-01-15  44.559006        0.0   0.000000        0.0
# 2015-01-21  45.512346        0.0   0.000000        0.0
# 2015-01-22  46.198198        0.0   0.000000        0.0
# 2015-01-23  48.000000        0.0   0.000000        0.0
# 2015-01-24  42.046632        0.0   0.000000        0.0
# 2015-01-25  41.364486        0.0   0.000000        0.0
# 2015-01-26  44.229358        0.0   0.000000        0.0
# 2015-01-27  39.092025        0.0   0.000000        0.0
# 2015-01-28  44.901786        0.0   0.000000        0.0
# 2015-01-29  45.587719        0.0   0.000000        0.0
# 2015-01-30  40.627660        0.0   0.000000        0.0
# 2015-01-31  43.607143        0.0   0.000000        0.0
# 2015-02-06  44.601770        0.0   0.000000        0.0
# 2015-02-07  37.575221        0.0   0.000000        0.0
# 2015-02-08  26.339506        0.0   0.000000        0.0
# 2015-02-09  29.903509        0.0   0.000000        0.0
# ...

# %%
data2.tail()
# Out:
#             Good  Hazardous   Moderate  Unhealthy  UnhealthySensitiveGroup  \
# Date
# 2017-12-28   NaN        NaN  61.308642        NaN                      NaN
# 2017-12-29   NaN        NaN  57.133333        NaN                      NaN
# 2017-12-30   NaN        NaN  72.699029        NaN                      NaN
# 2017-12-31   NaN        NaN  84.106667        NaN                      NaN
# 2018-01-01   NaN        NaN  55.562500        NaN                      NaN
#
#             VeryUnhealthy
# Date
# 2017-12-28            NaN
# 2017-12-29            NaN
# 2017-12-30            NaN
# 2017-12-31            NaN
# 2018-01-01            NaN

# %%
data1=data1[['Good', 'Moderate', 'UnhealthySensitiveGroup','Unhealthy','VeryUnhealthy','Hazardous' ]]

# %%
data=data[['Good', 'Moderate', 'UnhealthySensitiveGroup','Unhealthy']]

# %%
# # library
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
 
# # Your x and y axis
# x=range(1,6)
# y=[ [10,4,6,5,3], [12,2,7,10,1], [8,18,5,7,6] ]
 
# # use a known color palette (see..)
# pal = sns.color_palette("Set1")
# plt.stackplot(x,y, labels=['A','B','C'], colors=pal, alpha=0.4 )
# plt.legend(loc='upper right')
# plt.show()
 
# # create your palette
# pal = ["#9b59b6", "#e74c3c", "#34495e", "#2ecc71"]
# plt.stackplot(x,y, labels=['A','B','C'], colors=pal, alpha=0.4 )
# plt.legend(loc='upper right')

# %%
## COPY
# create your palette
pal = ["#00ff00", "#FFFF00", "#FFA500", "#FF0000","#800080","#471605"]
# ax = df.plot(kind='area', stacked=True, title='100 % stacked area chart')

# ax.set_ylabel('Percent (%)')
# ax.margins(0, 0) # Set margins to avoid "whitespace"

# plt.show()
ax = data1.plot(kind='area', figsize=(15,8),colors=pal,legend=False)
plt.ylim((0,500))
# data1.plot(kind='line', ax=ax, figsize=(15,8),colors=pal,legend=False)
# Out:
# /Users/pinkyjohar/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:186: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   warnings.warn(("'colors' is being deprecated. Please use 'color'"
# (0, 500)

# %%
data1[data1>200]
# Out:
#             Good  Moderate  UnhealthySensitiveGroup  Unhealthy  VeryUnhealthy  \
# Date
# 2015-03-02   NaN       NaN                      NaN        NaN            NaN
# 2015-03-07   NaN       NaN                      NaN        NaN            NaN
# 2015-03-08   NaN       NaN                      NaN        NaN            NaN
# 2015-03-09   NaN       NaN                      NaN        NaN            NaN
# 2015-03-15   NaN       NaN                      NaN        NaN            NaN
# 2015-03-16   NaN       NaN                      NaN        NaN            NaN
# 2015-03-18   NaN       NaN                      NaN        NaN            NaN
# 2015-03-27   NaN       NaN                      NaN        NaN            NaN
# 2015-03-30   NaN       NaN                      NaN        NaN            NaN
# 2015-03-31   NaN       NaN                      NaN        NaN            NaN
# 2015-04-03   NaN       NaN                      NaN        NaN            NaN
# ...

# %%
# create your palette
pal = ["#00ff00", "#FFFF00", "#FFA500", "#FF0000","#800080","#471605"]
# ax = df.plot(kind='area', stacked=True, title='100 % stacked area chart')

# ax.set_ylabel('Percent (%)')
# ax.margins(0, 0) # Set margins to avoid "whitespace"

# plt.show()
data1.plot(kind='area', figsize=(15,8),colors=pal,legend=False,lw=0)
# Out:
# /Users/pinkyjohar/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:186: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   warnings.warn(("'colors' is being deprecated. Please use 'color'"

# %%
# create your palette
pal = ["#00ff00", "#FFFF00", "#FFA500", "#FF0000"]
# ax = df.plot(kind='area', stacked=True, title='100 % stacked area chart')

# ax.set_ylabel('Percent (%)')
# ax.margins(0, 0) # Set margins to avoid "whitespace"
# ax = data.plot(kind='area', figsize=(15,8),colors=pal,legend=False)
#df_temp=pd.read_csv("USA_Combined_DataFrame.csv",parse_dates=['Date'])


data.plot.area(figsize=(15,8),colors=pal,legend=False,lw=0)
# plt.plot(df_temp['Date'],df_temp['DAILY_AQI_VALUE'],lw=0.5,color=[0.5,0.5,0.5])


plt.ylim((0,500))
# plt.show()
# plt.ylim((0,500))
# data.plot(kind='area', figsize=(15,8),colors=pal,legend=False)
# Out:
# /Users/pinkyjohar/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:186: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   warnings.warn(("'colors' is being deprecated. Please use 'color'"
# (0, 500)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
start_date=ts1.index[0]#'2015-01-01'
end_date=ts1.index[-1]#'2018-03-01'
fig,ax = plt.subplots(figsize=(12,8))
pal = ["#00ff00", "#FFFF00", "#FFA500", "#FF0000","#800080","#800000",'#808080']
plt.xlim(start_date,end_date)
plt.ylim(0,700)
alpha0 = 0.8
ax.add_patch(patches.Rectangle((start_date,500), 10000, 200, color=pal[-1], alpha=0.8))
ax.add_patch(patches.Rectangle((start_date,300), 10000, 200, color=pal[-2], alpha=0.8))
ax.add_patch(patches.Rectangle((start_date,200), 10000, 100, color=pal[-3], alpha=alpha0))
ax.add_patch(patches.Rectangle((start_date,150), 10000, 50, color=pal[-4], alpha=alpha0))
ax.add_patch(patches.Rectangle((start_date,100), 10000, 50, color=pal[-5], alpha=alpha0))
ax.add_patch(patches.Rectangle((start_date,50), 10000, 50, color=pal[-6], alpha=alpha0))
ax.add_patch(patches.Rectangle((start_date,0), 10000, 50, color=pal[-7], alpha=alpha0))
# plt.figure(figsize=(20,8))
plt.ylabel="Air Quality Index"
plt.plot(ts1.index, ts1.Delhi_AQI,color='k')
#plt.plot(ts.index,ts.DAILY_AQI_VALUE,color='gray')
plt.xticks(fontsize=12);
plt.yticks(fontsize=12)

#plt.xlabel=('Date')
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600., 700.]),
#  <a list of 8 Text yticklabel objects>)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
start_date=ts1.index[0]#'2015-01-01'
end_date=ts1.index[-1]#'2018-03-01'
fig,ax = plt.subplots(figsize=(12,8))
pal = ["#00ff00", "#FFFF00", "#FFA500", "#FF0000","#800080","#800000"]
plt.xlim(start_date,end_date)
plt.ylim(0,500)
alpha0 = 0.8
ax.add_patch(patches.Rectangle((start_date,300), 10000, 200, color=pal[-1], alpha=0.8))
ax.add_patch(patches.Rectangle((start_date,200), 10000, 100, color=pal[-2], alpha=alpha0))
ax.add_patch(patches.Rectangle((start_date,150), 10000, 50, color=pal[-3], alpha=alpha0))
ax.add_patch(patches.Rectangle((start_date,100), 10000, 50, color=pal[-4], alpha=alpha0))
ax.add_patch(patches.Rectangle((start_date,50), 10000, 50, color=pal[-5], alpha=alpha0))
ax.add_patch(patches.Rectangle((start_date,0), 10000, 50, color=pal[-6], alpha=alpha0))
# plt.figure(figsize=(20,8))
plt.plot(ts1.index, ts1.Delhi_AQI,color='k')
plt.plot(ts.index,ts.DAILY_AQI_VALUE,color='gray')
plt.xticks(fontsize=12);
plt.yticks(fontsize=12)

# plt.plot(df_temp['Date'],df_temp['DAILY_AQI_VALUE'],lw=0.5,color=[0.5,0.5,0.5])
# Out:
# (array([  0., 100., 200., 300., 400., 500.]),
#  <a list of 6 Text yticklabel objects>)

# %%
df[]
# Out:
#                      Delhi_AQI
# Date
# 2015-02-24 04:00:00      186.0
# 2015-02-24 05:00:00      179.0
# 2015-02-24 06:00:00      195.0
# 2015-02-24 07:00:00      207.0
# 2015-02-24 08:00:00      275.0

# %%
data2.plot.area()

# %%
# We need to transform the data from raw data to percentage (fraction)
data_perc = data.divide(data.sum(axis=0), axis=1)
 
# Make the plot

# %%
#  data_perc=pd.DataFrame()

# %%
data_perc.sample(20)
# Out:
#                          Good  Hazardous  Moderate  Unhealthy  \
# Date
# 2015-07-04 11:00:00       NaN        NaN       NaN        NaN
# 2016-12-14 02:00:00       NaN        NaN       NaN   0.000146
# 2016-01-08 12:00:00       NaN   0.000484       NaN        NaN
# 2015-05-10 17:00:00       NaN        NaN  0.000127        NaN
# 2015-11-02 01:00:00       NaN        NaN       NaN        NaN
# 2017-09-09 09:00:00       NaN        NaN       NaN   0.000113
# 2015-11-26 10:00:00       NaN        NaN       NaN   0.000130
# 2015-09-30 04:00:00  0.000306        NaN       NaN        NaN
# 2015-04-15 12:00:00  0.000398        NaN       NaN        NaN
# 2017-04-16 03:00:00       NaN        NaN       NaN   0.000139
# 2017-07-05 17:00:00       NaN        NaN       NaN   0.000114
# 2017-11-15 23:00:00       NaN        NaN       NaN        NaN
# 2017-02-06 19:00:00       NaN        NaN       NaN   0.000112
# 2015-12-06 05:00:00       NaN   0.000409       NaN        NaN
# ...

# %%
plt.stackplot(data.index,  data_perc["Good"],  data_perc["Moderate"],  data_perc["UnhealthySGroup"], data_perc["VUnhealthy"],data_perc["Hazardous"],labels=['Good','Moderate','UnhealthySGroup','VUnhealthy','Hazardous'])
# plt.stackplot(range(1,6),  data_perc["group_A"],  data_perc["group_B"],  data_perc["group_C"], labels=['A','B','C'])
# plt.legend(loc='upper left')
plt.legend(loc='upper left')
plt.margins(0,0)
plt.title('100 % stacked area chart')
plt.show()

# %%
# Dataset
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
 
# plot
df.plot.area()

# %%
# library
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

 
# Make data
data1 = pd.DataFrame({  'group_A':[1,4,6,8,9], 'group_B':[2,24,7,10,12], 'group_C':[2,8,5,10,6], }, index=range(1,6))
data1
# We need to transform the data from raw data to percentage (fraction)
data_perc1 = data1.divide(data1.sum(axis=1), axis=0)

# %%
data_perc1
# Out:
#     group_A   group_B   group_C
# 1  0.200000  0.400000  0.400000
# 2  0.111111  0.666667  0.222222
# 3  0.333333  0.388889  0.277778
# 4  0.285714  0.357143  0.357143
# 5  0.333333  0.444444  0.222222

# %%
 
# Make the plot
plt.stackplot(range(1,6),  data_perc["group_A"],  data_perc["group_B"],  data_perc["group_C"], labels=['A','B','C'])
plt.legend(loc='upper left')
plt.margins(0,0)
plt.title('100 % stacked area chart')
plt.show()

# %%
data
# Out:
#    group_A  group_B  group_C
# 1        1        2        2
# 2        4       24        8
# 3        6        7        5
# 4        8       10       10
# 5        9       12        6
